# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dense

# %%
#Generate dummy sequential data
# for instance, let's say we have 1000 samples, each with 10 time steps and 1 feature

X=np.random.random((1000, 10, 1))
y=np.random.random((1000,1))

# %%
# Define model

model=Sequential()
model.add(LSTM(50,input_shape=(X.shape[1], X.shape[2])))

model.add(Dense(1))

#Compile the model

model.compile(optimizer='adam',loss='mean_squared_error')

#summarize the Model


model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 50)                10400
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 10451 (40.82 KB)
# Trainable params: 10451 (40.82 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#Train the model
model.fit(X,y, epochs=20,batch_size=32)
# Out:
# Epoch 1/20
# 32/32 [==============================] - 3s 7ms/step - loss: 0.1549
# Epoch 2/20
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0887
# Epoch 3/20
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0873
# Epoch 4/20
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0864
# Epoch 5/20
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0858
# Epoch 6/20
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0851
# Epoch 7/20
# 32/32 [==============================] - 0s 9ms/step - loss: 0.0852
# Epoch 8/20
# 32/32 [==============================] - 0s 10ms/step - loss: 0.0850
# Epoch 9/20
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0844
# Epoch 10/20
# 32/32 [==============================] - 0s 10ms/step - loss: 0.0844
# Epoch 11/20
# 32/32 [==============================] - 0s 10ms/step - loss: 0.0841
# Epoch 12/20
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0836
# Epoch 13/20
# 32/32 [==============================] - 0s 9ms/step - loss: 0.0850
# Epoch 14/20
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0836
# Epoch 15/20
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0839
# Epoch 16/20
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0844
# Epoch 17/20
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0831
# Epoch 18/20
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0842
# Epoch 19/20
# 32/32 [==============================] - 0s 9ms/step - loss: 0.0832
# Epoch 20/20
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0831

# %%
loss=model.evaluate(X,y)
print(loss)
# Out:
# 32/32 [==============================] - 1s 4ms/step - loss: 0.0832
# 0.08320669084787369
